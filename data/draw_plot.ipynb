# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import matplotlib.pyplot as plt
import pandas as pd
import os

title = ["algorithmName", "referenceStringName", "memorySize", "pageFaults", "interrupts", "diskWrites"]
algorithmName = ["FIFO", "ARB", "ESC", "LRU-MFU"]
performance = ["Page faults", "Interrupts", "Disk writes"]
dataName = ["Random data", "Locality data", "Exponential random data"]
mark = ["o", "v", "s", "*", "D"]

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 18}

plt.rc('font', **font)

# %%
data = pd.read_csv(algorithmName[0] + ".csv")
data
# Out:
#    algorithmName               referenceStringName  memorySize  pageFaults  \
# 0           FIFO      uniform_reference_string.txt          20      197488
# 1           FIFO      uniform_reference_string.txt          40      193263
# 2           FIFO      uniform_reference_string.txt          60      189456
# 3           FIFO      uniform_reference_string.txt          80      185154
# 4           FIFO      uniform_reference_string.txt         100      180849
# 5           FIFO     locality_reference_string.txt          20         693
# 6           FIFO     locality_reference_string.txt          40         295
# 7           FIFO     locality_reference_string.txt          60         295
# 8           FIFO     locality_reference_string.txt          80         291
# 9           FIFO     locality_reference_string.txt         100         291
# 10          FIFO  exponential_reference_string.txt          20      195605
# 11          FIFO  exponential_reference_string.txt          40      191253
# 12          FIFO  exponential_reference_string.txt          60      186904
# 13          FIFO  exponential_reference_string.txt          80      182571
# 14          FIFO  exponential_reference_string.txt         100      178258
# 15          FIFO       normal_reference_string.txt          20      177936
# 16          FIFO       normal_reference_string.txt          40      156707
# 17          FIFO       normal_reference_string.txt          60      136376
# 18          FIFO       normal_reference_string.txt          80      117072
# 19          FIFO       normal_reference_string.txt         100       99186
#
#     interrupts  diskWrites
# 0       197488       99222
# 1       193263       98164
# 2       189456       97221
# 3       185154       96117
# 4       180849       94988
# 5          693         673
# 6          295         255
# 7          295         235
# 8          291         211
# 9          291         191
# 10      195605       98988
# 11      191253       97880
# 12      186904       96724
# 13      182571       95560
# 14      178258       94447
# 15      177936       94480
# 16      156707       88450
# 17      136376       82013
# 18      117072       75326
# 19       99186       68270

# %%
imgPath = 'img/'
isExist = os.path.exists(imgPath)
if not isExist:
    os.makedirs(imgPath)
    print("create img directory")
# Out:
# create img directory

# %%
# 1. The plots between performance and frames each algorithm.
for i in range(4) : # of algorithm
    data = pd.read_csv(algorithmName[i] + ".csv")
    k = 0
    for j in range(0, 15, 5): # (0, # of needed row, # of memorySize)
    
        plt.plot(data[title[2]][j:j+5], data[title[3]][j:j+5], label=performance[0], linewidth=5, linestyle='--', marker=mark[0], markersize=15)
        plt.plot(data[title[2]][j:j+5], data[title[4]][j:j+5], label=performance[1], linewidth=5, linestyle=':', marker=mark[1], markersize=15)
        plt.plot(data[title[2]][j:j+5], data[title[5]][j:j+5], label=performance[2], linewidth=5, alpha=0.5, marker=mark[2], markersize=15)
        
        plt.title(algorithmName[i] + " : " + dataName[k], fontsize=36, fontweight='bold')
        plt.xlabel("The number of frames", fontsize=24, fontweight='bold')
        plt.ylabel("Values", fontsize=24, fontweight='bold')
        plt.xlim(20, 100)
        plt.ylim(0)
        plt.legend()
        plt.grid(True)
        
        fig = plt.gcf()
        fig.set_size_inches(16, 12)
        k += 1
        fig.savefig("img/" + algorithmName[i] + str(k) + '.jpg', dpi=100)
        plt.clf()
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
# 2. The plots between performance and frames each data.
FIFO = pd.read_csv(algorithmName[0] + ".csv")
ARB = pd.read_csv(algorithmName[1] + ".csv")
ESC = pd.read_csv(algorithmName[2] + ".csv")
LRUMFU = pd.read_csv(algorithmName[3] + ".csv")

# %%
for i in range(3, 6, 1) : 
    for j in range(0, 15, 5) :
        plt.plot(FIFO[title[2]][j:j+5],    FIFO[title[i]][j:j+5], label=algorithmName[0], linewidth=5, linestyle='--', marker=mark[0], markersize=15)
        plt.plot(ARB[title[2]][j:j+5],     ARB[title[i]][j:j+5], label=algorithmName[1], linewidth=5, linestyle=':', marker=mark[1], markersize=15)
        plt.plot(ESC[title[2]][j:j+5],     ESC[title[i]][j:j+5], label=algorithmName[2], linewidth=5, linestyle='-', marker=mark[2], markersize=15, alpha=0.5)
        plt.plot(LRUMFU[title[2]][j:j+5],  LRUMFU[title[i]][j:j+5], label=algorithmName[3], linewidth=5, linestyle=':', marker=mark[3], markersize=15, alpha=0.5)
        
        plt.title(dataName[int(j/5)], fontsize=36, fontweight='bold')
        plt.xlabel("The number of frames", fontsize=24, fontweight='bold')
        plt.ylabel("The number of " + performance[i-3].lower(), fontsize=24, fontweight='bold')
        plt.xlim(20, 100)
        #plt.ylim(0)
        plt.legend()
        plt.grid(True)
        
        fig = plt.gcf()
        fig.set_size_inches(16, 12)
        fig.savefig("img/" + dataName[int(j/5)] + str(i-1) + '.jpg', dpi=100)
        plt.clf()
        # print(str(int(j/5+1)) + " " +str(i-1))
